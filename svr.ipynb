# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
mammals=pd.read_csv(r"C:\Users\archa\OneDrive\Desktop\Downloads\mammals.csv").sort_values('body')
mammals
# Out:
#                        Mammal      body    brain
# 13  Lesser short-tailed shrew     0.005     0.14
# 39           Little brown bat     0.010     0.25
# 38                      Mouse     0.023     0.40
# 19              Big brown bat     0.023     0.30
# 54                 Musk shrew     0.048     0.33
# ..                        ...       ...      ...
# 3                         Cow   465.000   423.00
# 21                      Horse   521.000   655.00
# 27                    Giraffe   529.000   680.00
# 18             Asian elephant  2547.000  4603.00
# 32           African elephant  6654.000  5712.00
#
# [62 rows x 3 columns]

# %%
body=mammals[['body']].values
brain=mammals[['brain']].values
body
# Out:
# array([[5.000e-03],
#        [1.000e-02],
#        [2.300e-02],
#        [2.300e-02],
#        [4.800e-02],
#        [6.000e-02],
#        [7.500e-02],
#        [1.010e-01],
#        [1.040e-01],
#        [1.200e-01],
#        [1.220e-01],
#        [2.000e-01],
#        [2.800e-01],
#        [4.250e-01],
#        [4.800e-01],
#        [5.500e-01],
#        [7.500e-01],
#        [7.850e-01],
#        [9.000e-01],
#        [9.200e-01],
#        [1.000e+00],
#        [1.040e+00],
#        [1.350e+00],
#        [1.400e+00],
#        [1.410e+00],
#        [1.620e+00],
#        [1.700e+00],
#        [2.000e+00],
#        [2.500e+00],
#        [3.000e+00],
#        [3.300e+00],
#        [3.385e+00],
#        [3.500e+00],
#        [3.500e+00],
#        [3.600e+00],
#        [4.050e+00],
#        [4.190e+00],
#        [4.235e+00],
#        [4.288e+00],
#        [6.800e+00],
#        [1.000e+01],
#        [1.055e+01],
#        [1.483e+01],
#        [2.766e+01],
#        [3.500e+01],
# ...

# %%
brain
# Out:
# array([[1.400e-01],
#        [2.500e-01],
#        [4.000e-01],
#        [3.000e-01],
#        [3.300e-01],
#        [1.000e+00],
#        [1.200e+00],
#        [4.000e+00],
#        [2.500e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [1.900e+00],
#        [6.400e+00],
#        [1.550e+01],
#        [2.400e+00],
#        [1.230e+01],
#        [3.500e+00],
#        [2.600e+00],
#        [5.700e+00],
#        [6.600e+00],
#        [5.500e+00],
#        [8.100e+00],
#        [1.250e+01],
#        [1.750e+01],
#        [1.140e+01],
#        [6.300e+00],
#        [1.230e+01],
#        [1.210e+01],
#        [2.500e+01],
#        [2.560e+01],
#        [4.450e+01],
#        [3.900e+00],
#        [1.080e+01],
#        [2.100e+01],
#        [1.700e+01],
#        [5.800e+01],
#        [5.040e+01],
#        [3.920e+01],
#        [1.790e+02],
#        [1.150e+02],
#        [1.795e+02],
#        [9.820e+01],
#        [1.150e+02],
#        [5.600e+01],
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn import svm
print(body.shape)
# Out:
# (62, 1)

# %%
svm_linear=svm.SVR(kernel='linear',C=1e1)
svm_rbf=svm.SVR(kernel='rbf',C=1e1)

# %%
svm_linear.fit(np.log(body),np.log(brain))
svm_rbf.fit(np.log(body),np.log(brain))
logfit=LinearRegression().fit(np.log(body),np.log(brain))
# Out:
# C:\Users\archa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\archa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
mammals['lnr']=np.exp(logfit.predict(np.log(body)))
mammals['rbf']=np.exp(svm_rbf.predict(np.log(body)))
mammals['linear']=np.exp(svm_linear.predict(np.log(body)))

# %%
mammals
# Out:
#                        Mammal      body    brain          lnr          rbf  \
# 13  Lesser short-tailed shrew     0.005     0.14     0.157571     0.154752
# 39           Little brown bat     0.010     0.25     0.265311     0.177612
# 38                      Mouse     0.023     0.40     0.496205     0.360732
# 19              Big brown bat     0.023     0.30     0.496205     0.360732
# 54                 Musk shrew     0.048     0.33     0.862650     0.856244
# ..                        ...       ...      ...          ...          ...
# 3                         Cow   465.000   423.00   855.487784   632.249121
# 21                      Horse   521.000   655.00   931.827772   724.034112
# 27                    Giraffe   529.000   680.00   942.562742   737.490629
# 18             Asian elephant  2547.000  4603.00  3071.786297  4162.968902
# 32           African elephant  6654.000  5712.00  6322.437045  5168.858092
#
#          linear
# 13     0.140863
# 39     0.237586
# ...
